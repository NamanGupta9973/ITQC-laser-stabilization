# %%
import matplotlib.pyplot as plt
from moku.instruments import MultiInstrument
from moku.instruments import PIDController, WaveformGenerator
from moku.instruments import Datalogger
import os
import time

# %%
# WITH PID
# m = MultiInstrument('10.2.10.7', platform_id = 4, force_connect=True)
m = MultiInstrument('localhost:1025', platform_id = 4, force_connect=True)
try:
    datal = m.set_instrument(2, Datalogger)
    pid = m.set_instrument(3, PIDController)
    wg = m.set_instrument(4, WaveformGenerator)
    
    # set up connections for multiinstrument mode
    connections = [
        dict(source="Input3", destination="Slot3InA"),  # input 3 -> PID input
        dict(source="Slot3OutA", destination="Slot4InA"),  # PID output -> waveform generator input (for amplitude modulation)
        dict(source="Slot4OutA", destination="Output4"),  # waveform generator (RF) -> Output 4
        dict(source="Input1", destination="Slot2InA"), # input 1 = sensor/power meter -> data logger input
        dict(source="Input3", destination="Slot2InB"), # input 3 = PD output -> data logger input
    ]
    print(m.set_connections(connections=connections))

    m.set_frontend(channel = 1, impedance='1MOhm', coupling='DC', attenuation ='-20dB') # configure input port 1 - sensor and power meter
    m.set_frontend(channel = 3, impedance='1MOhm', coupling='DC', attenuation='0dB') # configure input port 3 PID input

    # additional code if you don't want to start right away and want to wait for sometime----------------
    # Turn OFF the waveform generator initially
    wg.generate_waveform(channel=1, type='DC', dc_level=0, amplitude=0)

    # print("Waiting 1 hour before starting data collection...")
    # time.sleep(30)  # **Wait 1 hour**
    # ------------------------------------------------------------------------------------------------

    # waveform generator and amplitude modulation--------------------------------------------------------------
    wg.generate_waveform(channel=1, type='Sine', frequency=80e6, amplitude=0.79621/2)  # V_peak = Vpp/2
    # some commonly used values: 0 dBm : 0.63246 Vpp
    #                            1 dBm : 0.70963 Vpp
    #                            2 dBm : 0.79621 Vpp
    #                            6 dBm : 1.2619 Vpp
    #                            10 dBm: 2.0000 Vpp
    wg.set_modulation(channel=1, type='Amplitude', source='InputA', depth=100) # amplitude modulation controlled by PID
    # -------------------------------------------------------------------------------------------------------------

    # PID------------------------------------------------------------------------------------------------
    # pid.set_by_frequency(channel = 1, prop_gain = 4, int_crossover = 10e3)  # P gain in dB, I crossover freq in Hz
    # pid.set_by_frequency(channel = 1, prop_gain = 20, int_crossover = 1e2)  # P gain in dB, I crossover freq in Hz
    pid.set_by_frequency(channel = 1, prop_gain = 23, int_crossover = 60.17)
    #prop_gain = 38, int_crossover = 36e3)#, diff_crossover = 240e3)  # P gain in dB, I crossover freq in Hz
    pid.set_control_matrix(channel = 1, input_gain1 = 1, input_gain2 = 0)  # input matrix
    pid.set_input_offset(channel = 1, offset = -0.0095) # bias
    pid.enable_output(channel = 1, signal = True, output = True)
    #----------------------------------------------------------------------------------------------------
    time.sleep(10)  # wait 15 seconds while the signal stabilizes
    print("Just finished waiting 30 seconds, now starting data collection...")
    
    # Data collection settings
    num_iterations = 18          # number of times when you want to collect data
    logging_duration = 60       # Each logging session lasts 60 seconds
    interval_between_logs = 600 - logging_duration  # Wait 110 seconds before next collection
    
    for i in range(num_iterations):
        print(f"Starting data collection {i+1}/{num_iterations}...")

        # Generate a unique filename using timestamp
        filename = f"PI.2dBm.both_{time.strftime('%Y%m%d_%H%M%S')}.li"

        # Start logging
        datal.enable_input(channel=1, enable=True)
        datal.set_samplerate(10)
        datal.set_acquisition_mode(mode='Precision')
        logFile = datal.start_logging(duration=logging_duration, file_name_prefix=filename)

        # Track progress
        complete = False
        while not complete:
            time.sleep(0.5)  # Sleep to avoid excessive polling
            progress = datal.logging_progress()
            complete = progress['complete']
            # if 'time_remaining' in progress:
            #     print(f"Remaining time {progress['time_remaining']} seconds")

        # Download log file
        # local_path = os.path.join(os.getcwd(), filename)
        # datal.download("persist", logFile['file_name'], local_path)
        # print(f"Downloaded log file to: {local_path}")

        # Wait before the next logging session
        if i < num_iterations - 1:
            print(f"Waiting {interval_between_logs} seconds before next collection...\n")
            time.sleep(interval_between_logs)

    print("Data collection complete!")

except Exception as e:
    print(f'Exception occurred: {e}')
finally:
    # Close the connection to the Moku device
    # This ensures network resources and released correctly
    m.set_connections(connections=connections) # this comment is what the liquid instruments tech guy added
    m.relinquish_ownership()

# i = WaveformGenerator('10.2.10.7', force_connect=True)
i = WaveformGenerator('localhost:1025', force_connect=True)
i.generate_waveform(channel=4, type='DC', dc_level=0, amplitude=0)
i.relinquish_ownership()
# Out:
# [{'destination': 'Slot2InA', 'source': 'Input1'}, {'destination': 'Slot2InB', 'source': 'Input3'}, {'destination': 'Slot3InA', 'source': 'Input3'}, {'destination': 'Slot3InB', 'source': 'Slot2OutB'}, {'destination': 'Slot4InA', 'source': 'Slot3OutA'}, {'destination': 'Slot4InB', 'source': 'Slot3OutB'}, {'destination': 'Output4', 'source': 'Slot4OutA'}]
# Just finished waiting 30 seconds, now starting data collection...
# Starting data collection 1/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 2/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 3/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 4/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 5/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 6/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 7/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 8/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 9/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 10/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 11/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 12/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 13/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 14/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 15/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 16/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 17/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 18/18...
# Data collection complete!

# %%
# WITHOUT PID, with RF
# m = MultiInstrument('10.2.10.7', platform_id=4, force_connect=True) # connect to Moku device
m = MultiInstrument('localhost:1025', platform_id = 4, force_connect=True)

try:
    # Set up instruments
    datal = m.set_instrument(2, Datalogger) # for the sensor and power meter on the transmitted path
    wg = m.set_instrument(4, WaveformGenerator)

    # Configure connections
    connections = [
        dict(source="Slot4OutA", destination="Output4"),  # Waveform generator -> Output 4
        dict(source="Input1", destination="Slot2InA"),  # Input 1 -> data logger input for sensor/power meter on the transmitted path
        dict(source="Input3", destination="Slot2InB"),  # Input 2 -> data logger input for PD on the reflected path
    ]
    print(m.set_connections(connections=connections))

    # Configure frontend (input)
    m.set_frontend(channel=1, impedance='1MOhm', coupling='DC', attenuation='-20dB') # -20 dB will divide voltage by 10, input for sensor
    m.set_frontend(channel=3, impedance='1MOhm', coupling='DC', attenuation='0dB') # input for PD

    # **Turn OFF the waveform generator initially**
    wg.generate_waveform(channel=1, type='DC', dc_level=0, amplitude=0)

    # print("Waiting 1 hour before starting data collection...")
    # time.sleep(60)  # **Wait 1 hour**

    # **Data collection settings**
    num_iterations = 1          # Collect data 36 times ~ 6 hours
    logging_duration = 60*2       # Each logging session lasts 10 seconds
    interval_between_logs = 600 - logging_duration  # Wait 110 seconds before next collection

    for i in range(num_iterations):
        print(f"Starting data collection {i+1}/{num_iterations}...")

        # **Turn ON the waveform generator before data collection**
        wg.generate_waveform(channel=1, type='Sine', frequency=80e6, amplitude=0.79621 / 2) # 0 dB

        # Generate a unique filename using timestamp
        filename = f"noPID_sensor&PD_{time.strftime('%Y%m%d_%H%M%S')}.li"
        # filename_PD = f"withoutPID_PD_{time.strftime('%Y%m%d_%H%M%S')}.li"

        # # start logging for sensor
        # datal_sensor.enable_input(channel=1, enable=True)
        # datal_sensor.set_samplerate(10)
        # datal_sensor.set_acquisition_mode(mode='Precision')
        # logFile_sensor = datal_sensor.start_logging(duration=logging_duration, file_name_prefix=filename_sensor)

        # start logging
        datal.enable_input(channel=2, enable=True)
        datal.enable_input(channel=1, enable=True)
        datal.set_samplerate(10)
        datal.set_acquisition_mode(mode='Precision')
        logFile = datal.start_logging(duration=logging_duration, file_name_prefix=filename)

        # track progress for both loggers
        complete = False
        while not complete:
            time.sleep(0.5)
            progress = datal.logging_progress()
            complete = progress['complete']
            # if 'time_remaining' in progress:
            #     print(f"Remaining time {progress['time_remaining']} seconds")

        # download log file
        # local_path = os.path.join(os.getcwd(), filename)
        # datal.download("persist", logFile['file_name'], local_path)
        # print(f"Downloaded log file to: {local_path}")

        # wait before the next logging session
        if i < num_iterations - 1:
            print(f"Waiting {interval_between_logs} seconds before next collection...\n")
            time.sleep(interval_between_logs)

    print("Data collection complete!")

except Exception as e:
    print(f'Exception occurred: {e}')

finally:
    # Turn OFF the waveform generator before exiting
    #wg.generate_waveform(channel=1, type='DC', dc_level=0, amplitude=0)
    m.set_connections(connections=connections) # this comment is what the liquid instruments tech guy added

    # Close the connection to the Moku device
    m.relinquish_ownership()

i = WaveformGenerator('10.2.10.7', force_connect=True)
i.generate_waveform(channel=4, type='DC', dc_level=0, amplitude=0) # stop generating by applying a 0 amplitude wave
i.relinquish_ownership()
# Out:
# [{'destination': 'Slot2InA', 'source': 'Input1'}, {'destination': 'Slot2InB', 'source': 'Input3'}, {'destination': 'Output4', 'source': 'Slot4OutA'}]
# Starting data collection 1/1...
# Data collection complete!

# %%
i = WaveformGenerator('10.2.10.7', force_connect=True)
i.generate_waveform(channel=4, type='DC', dc_level=0, amplitude=0) # stop generating by applying a 0 amplitude wave
i.relinquish_ownership()

# %%
# WITHOUT PID, WITHOUT RF
# m = MultiInstrument('10.2.10.7', platform_id = 4, force_connect=True)
m = MultiInstrument('localhost:1025', platform_id = 4, force_connect=True)
try:
    datal = m.set_instrument(2, Datalogger)
    
    # set up connections for multiinstrument mode
    connections = [
        dict(source="Input1", destination="Slot2InA"), # input 1 = sensor/power meter -> data logger input
        dict(source="Input3", destination="Slot2InB"), # input 3 = PD output -> data logger input
    ]
    print(m.set_connections(connections=connections))

    m.set_frontend(channel = 1, impedance='1MOhm', coupling='DC', attenuation ='-20dB') # configure input port 1 - sensor and power meter
    m.set_frontend(channel = 3, impedance='1MOhm', coupling='DC', attenuation='0dB') # configure input port 3 PID input

    # additional code if you don't want to start right away and want to wait for sometime----------------
    # Turn OFF the waveform generator initially

    # print("Waiting 1 hour before starting data collection...")
    # time.sleep(30)  # **Wait 1 hour**
    # ------------------------------------------------------------------------------------------------

    time.sleep(10)  # wait 15 seconds while the signal stabilizes
    print("Just finished waiting 10 seconds, now starting data collection...")
    
    # Data collection settings
    num_iterations = 18          # number of times when you want to collect data
    logging_duration = 60       # Each logging session lasts 60 seconds
    interval_between_logs = 600 - logging_duration  # Wait 110 seconds before next collection
    
    for i in range(num_iterations):
        print(f"Starting data collection {i+1}/{num_iterations}...")

        # Generate a unique filename using timestamp
        filename = f"noPI.noRF.both_{time.strftime('%Y%m%d_%H%M%S')}.li"

        # Start logging
        datal.enable_input(channel=1, enable=True)
        datal.set_samplerate(10)
        datal.set_acquisition_mode(mode='Precision')
        logFile = datal.start_logging(duration=logging_duration, file_name_prefix=filename)

        # Track progress
        complete = False
        while not complete:
            time.sleep(0.5)  # Sleep to avoid excessive polling
            progress = datal.logging_progress()
            complete = progress['complete']
            # if 'time_remaining' in progress:
            #     print(f"Remaining time {progress['time_remaining']} seconds")

        # Download log file
        # local_path = os.path.join(os.getcwd(), filename)
        # datal.download("persist", logFile['file_name'], local_path)
        # print(f"Downloaded log file to: {local_path}")

        # Wait before the next logging session
        if i < num_iterations - 1:
            print(f"Waiting {interval_between_logs} seconds before next collection...\n")
            time.sleep(interval_between_logs)

    print("Data collection complete!")

except Exception as e:
    print(f'Exception occurred: {e}')
finally:
    # Close the connection to the Moku device
    # This ensures network resources and released correctly
    m.set_connections(connections=connections) # this comment is what the liquid instruments tech guy added
    m.relinquish_ownership()

# i = WaveformGenerator('10.2.10.7', force_connect=True)
i = WaveformGenerator('localhost:1025', force_connect=True)
i.generate_waveform(channel=4, type='DC', dc_level=0, amplitude=0)
i.relinquish_ownership()
# Out:
# [{'destination': 'Slot2InA', 'source': 'Input1'}, {'destination': 'Slot2InB', 'source': 'Input3'}]
# Just finished waiting 10 seconds, now starting data collection...
# Starting data collection 1/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 2/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 3/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 4/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 5/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 6/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 7/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 8/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 9/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 10/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 11/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 12/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 13/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 14/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 15/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 16/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 17/18...
# Waiting 540 seconds before next collection...
#
# Starting data collection 18/18...
# Data collection complete!
